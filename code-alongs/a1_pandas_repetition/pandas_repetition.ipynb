# %% [markdown]
# # Pandas repetition
#
# ## Read in calories into a dataframe

# %%
import pandas as pd 

df = pd.read_excel("calories.xlsx")
df.head() # picks the top 5 by default
# Out:
#   FoodCategory             FoodItem per100grams Cals_per100grams  \
# 0  CannedFruit           Applesauce        100g           62 cal
# 1  CannedFruit      Canned Apricots        100g           48 cal
# 2  CannedFruit  Canned Blackberries        100g           92 cal
# 3  CannedFruit   Canned Blueberries        100g           88 cal
# 4  CannedFruit      Canned Cherries        100g           54 cal
#
#   KJ_per100grams
# 0         260 kJ
# 1         202 kJ
# 2         386 kJ
# 3         370 kJ
# 4         227 kJ

# %%
df.head(3)
# Out:
#   FoodCategory             FoodItem per100grams Cals_per100grams  \
# 0  CannedFruit           Applesauce        100g           62 cal
# 1  CannedFruit      Canned Apricots        100g           48 cal
# 2  CannedFruit  Canned Blackberries        100g           92 cal
#
#   KJ_per100grams
# 0         260 kJ
# 1         202 kJ
# 2         386 kJ

# %%
df.tail() # five last rows
# Out:
#      FoodCategory          FoodItem per100grams Cals_per100grams  \
# 2220      Spreads  Sunflower Butter        100g          617 cal
# 2221      Spreads          Tapenade        100g          233 cal
# 2222      Spreads   Unsalted Butter        100g          717 cal
# 2223      Spreads          Vegemite        100g          180 cal
# 2224      Spreads        Wild Honey        100g          286 cal
#
#      KJ_per100grams
# 2220        2591 kJ
# 2221         979 kJ
# 2222        3011 kJ
# 2223         756 kJ
# 2224        1201 kJ

# %%
df.sample(3) # 3 rows at random
# Out:
#           FoodCategory        FoodItem per100grams Cals_per100grams  \
# 2151  Sauces&Dressings  Greek Dressing       100ml          467 cal
# 782            Sausage          Salami        100g          336 cal
# 1693           Legumes      Soy Yogurt        100g           66 cal
#
#      KJ_per100grams
# 2151        1961 kJ
# 782         1411 kJ
# 1693         277 kJ

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FoodCategory      2225 non-null   object
#  1   FoodItem          2225 non-null   object
#  2   per100grams       2225 non-null   object
#  3   Cals_per100grams  2225 non-null   object
#  4   KJ_per100grams    2225 non-null   object
# dtypes: object(5)
# memory usage: 87.0+ KB

# %%
df["per100grams"].value_counts()
# Out:
# per100grams
# 100g     1802
# 100ml     423
# Name: count, dtype: int64
